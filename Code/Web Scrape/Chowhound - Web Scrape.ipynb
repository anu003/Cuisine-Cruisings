# %%
from time import sleep
import requests
from bs4 import BeautifulSoup
from math import ceil
import pandas as pd
from pymongo import MongoClient

# %%
SCRAPING_REQUEST_STAGGER = 4.0 # in seconds
# the link for Chowhound recipes
URL = 'http://www.chowhound.com/recipes?page={}'
NUMBER_OF_RECIPES_PER_PAGE = 27

# %% [markdown]
# DB_NAME = 'PROJECT_RECIPIES'
# COLLECTION_NAME = 'Chowhound'
#
# client = MongoClient()
# db = client[DB_NAME]
# coll = db[COLLECTION_NAME]

# %%
def get_content_from_url(link):
    # make request with the input link and return the content of the web link
    sleep(SCRAPING_REQUEST_STAGGER)        
    response = requests.get(link)
    
    # if the status code of response is not 200, then raise a warning
    if response.status_code != 200:
        return False
    
    return response.content

# %%
def get_number_of_pages():
    # find number of recipes from the first recipe page
    
    # create a full link using the cuisine_link and cuisine name to obtain web content from link
    first_page_link = URL.format("1")
    cuisine_recipes = get_content_from_url(first_page_link)
    
    # if no content is returned from the cuisine link page
    if not cuisine_recipes:
        print "no content for:", first_page_link
        return None  
    
    # convert web content to soup to better access the content
    soup_cuisine = BeautifulSoup(cuisine_recipes)
    
    # select characters from phrase and convert it into integer
    return int(soup_cuisine.find("span", {"class": "last"}).a["href"].split('=')[1])

# %%
def get_recipe_links_by_page(page):
    # create link for given cuisine and page number and obtain recipe links from page 
    
    # create a full link using the cuisine_link and cuisine name to obtain web content from link
    page_link = URL.format(page)
    cuisine_recipe_links = get_content_from_url(page_link)
    if not cuisine_recipe_links:
        print "no content for:", link
        return None
    
    soup_search = BeautifulSoup(cuisine_recipe_links)

    # return the list of links for the cuisine page
    return soup_search.find_all("div", {"class": "image_link_medium"})

# %%
def get_recipe(recipe_link):
    # make web request and obtain site content for recipe page
    recipe_response = get_content_from_url(recipe_link)
    if not recipe_response:
        print "no content for:", recipe_link
        return None
    
    return BeautifulSoup(recipe_response)

# %%
def get_recipe_title(soup_recipe):
    # recipe title
    return soup_recipe.find("h1",{"itemprop":"name"}).get_text().strip()

# %%
def get_recipe_chef(soup_recipe):
    # recipe chef name
    chef_name = soup_recipe.find("span",{"itemprop":"author"})
    
    # if chef name is not there for the recipe
    if not chef_name:
        return None
    
    # strip new line characters on both sides and the "By " from front
    return chef_name.get_text().strip()

# %%
def get_description(soup_recipe):
    # recipe description
    summary = soup_recipe.find("div",{"itemprop":"description"})
    
    # if summary is not there for the recipe
    if not summary:
        return None
    
    return summary.get_text().strip()

# %%
def get_recipe_ingredients(soup_recipe):
    #recipe ingredients
    ingredients_list = soup_recipe.find_all("li", {"itemprop":"ingredients"})
    ingredients = []
    for ing in ingredients_list:
        ingredients.append(ing.get_text())
    return ingredients

# %%
def get_recipe_preperation(soup_recipe):
    # recipe preperation steps
    prep_steps = soup_recipe.find("div", {"itemprop":"recipeInstructions"}).find_all("li")
    prep = []
    for step in prep_steps:
        # get text for the each step and strip of new line characters at both ends
        prep.append(step.get_text().strip())
    return prep

# %%
def get_recipe_time(soup_recipe):
    # recipe preperation time
    total_time = soup_recipe.find("time", {"itemprop":"totalTime"})
    # if recipe has total_time given
    if total_time:
        total_time = total_time.get_text().strip()
    else:
        total_time = None
    # recipe cooking time
    active_time = soup_recipe.find("span", {"class":"frr_totaltime frr_active"})
    # if recipe has active_time given
    if active_time:
        active_time = active_time.find("time").get_text().strip()
    else:
        active_time = None
    return total_time, active_time

# %%
def get_servings(soup_recipe):
    # recipe servings
    servings = soup_recipe.find("span", {"itemprop":"recipeYield"})
    if not servings:
        return None
    
    return servings.get_text()

# %%
def get_recipe_difficulty(soup_recipe):
    # recipe difficulty level
    difficulty = soup_recipe.find("span", {"class":"frr_difficulty fr_sep"})
    if not difficulty:
        return None
    
    return difficulty.get_text().strip()

# %%
def get_ratings(soup_recipe):
    # recipe ratings
    ratings = soup_recipe.find("span", {"itemprop":"ratingValue"})
    # if recipe has ratings
    if not ratings:
        ratings = None
    else:
        ratings = ratings.get_text()
    rating_count = soup_recipe.find("span", {"itemprop":"reviewCount"})
    if not rating_count:
        rating_count = None
    else:
        rating_count = rating_count.get_text()
    return ratings, rating_count

# %%
def get_nutrition_per_serving(soup_recipe):
    # recipe servings
    nutritional_info = soup_recipe.find("div", {"class":"nutritional-info"})
    if not nutritional_info:
        return None
    
    return nutritional_info.get_text()

# %%
def get_image_source(soup_recipe):
    # recipe image source
    image_source = soup_recipe.find("img", {"id":"recipe_top_img"})
    if not image_source:
        return None
    
    return image_source["src"]

# %%
def get_recipe_details(recipe_links):
    # obtain necessary recipe details from recipe page
    
    cuisine_recipes = {}
    
    # loop over recipe links to get recipe details for each recipe page
    for r in recipe_links:
        if "www.chowhound.com" in r.a["href"]:
            recipe = {}
            recipe['r_link'] = r.a["href"]
            print "recipe link: ", recipe['r_link']

            sleep(SCRAPING_REQUEST_STAGGER)        
            soup_recipe = get_recipe(recipe['r_link'])

            recipe['recipe title'] = get_recipe_title(soup_recipe)
            recipe['chef'] = get_recipe_chef(soup_recipe)
            recipe['description'] = get_description(soup_recipe)
            recipe['ingredient list'] = get_recipe_ingredients(soup_recipe)
            recipe['preperation steps'] = get_recipe_preperation(soup_recipe)
            recipe['total_time'], recipe['active_time'] = get_recipe_time(soup_recipe)
            recipe['servings'] = get_servings(soup_recipe)
            recipe['skill_level'] = get_recipe_difficulty(soup_recipe)
            recipe['rating'], recipe['rating count'] = get_ratings(soup_recipe)
            recipe['nutritional_info'] = get_nutrition_per_serving(soup_recipe)
            recipe['image_source'] = get_image_source(soup_recipe)
            
            cuisine_recipes[recipe['recipe title']] = recipe
    
    return cuisine_recipes

# %%
def get_recipe_links(pages):
    # loop over each page in the cuisine to obtain all the recipe details
    
    recipe_links = []
    page_start, page_end = 31, 40
    print "page_start: %d, page_end: %d" % (page_start, page_end)
    
    for page in xrange(page_start, page_end+1):#pages + 1):
        sleep(SCRAPING_REQUEST_STAGGER)
        # recipe links from each cuisine search page
        recipe_links.extend(get_recipe_links_by_page(page))
        
    # get recipe details for unique recipe links
    cuisine_recipes = get_recipe_details(list(set(recipe_links)))
    return cuisine_recipes

# %%
def get_recipes(num_of_pages):
    # loop over each cuisine and store data regarding that cuisine recipies
    
    # to store the data in a pandas Dataframe
    cuisine_df = pd.DataFrame()
    
    cuisine_dict = {}
        
    cuisine_dict['cuisine'] = 'Unknown'
    cuisine_dict['source'] = 'Chowhound'

    cuisine_dict['num_recipes'] = NUMBER_OF_RECIPES_PER_PAGE * num_of_pages

    # convert number of recipes into pages to scrape
    cuisine_dict['pages'] = num_of_pages

    # print the cuisine details
    print '#####'
    print "Cuisine: %s \t Number of recipes: %r \t\t Number of pages: %r" \
                % (cuisine_dict['cuisine'], cuisine_dict['num_recipes'], cuisine_dict['pages'])

    cuisine_dict['recipes_details'] = get_recipe_links(cuisine_dict['pages'])

    #coll.insert_one(cuisine_dict)

    # convert the dictionary into a dataframe and append it to the final dataframe
    cuisine_df = pd.DataFrame.from_dict(cuisine_dict, orient='columns')

    return cuisine_df

# %%
if __name__ == '__main__':
    
    #coll.delete_many({})
    num_of_pages = get_number_of_pages()
    cuisine_dataframe = get_recipes(num_of_pages)
# Out:
# #####
# Cuisine: Unknown 	 Number of recipes: 6318 		 Number of pages: 234
# page_start: 31, page_end: 40
# recipe link:  http://www.chowhound.com/recipes/the-sweeter-welcome-punch-30602
# recipe link:  http://www.chowhound.com/recipes/tarragon-chicken-salad-30698
# recipe link:  http://www.chowhound.com/recipes/copa-verde-11038
# recipe link:  http://www.chowhound.com/recipes/roasted-shrimp-with-romesco-sauce-10752
# recipe link:  http://www.chowhound.com/recipes/green-garlic-aioli-11705
# recipe link:  http://www.chowhound.com/recipes/ham-cheese-and-mushroom-strata-30893
# recipe link:  http://www.chowhound.com/recipes/stuffed-bell-peppers-with-feta-and-herbs-10934
# recipe link:  http://www.chowhound.com/recipes/orange-honey-and-thyme-brined-turkey-breast-30869
# recipe link:  http://www.chowhound.com/recipes/warm-cheesy-swiss-chard-and-roasted-garlic-dip-30685
# recipe link:  http://www.chowhound.com/recipes/sauteed-asian-broccoli-30676
# recipe link:  http://www.chowhound.com/recipes/rib-eye-with-pineapple-and-blue-cheese-30877
# recipe link:  http://www.chowhound.com/recipes/easy-chicken-noodle-soup-30675
# recipe link:  http://www.chowhound.com/recipes/smores-ice-cream-30805
# recipe link:  http://www.chowhound.com/recipes/egg-salad-30681
# recipe link:  http://www.chowhound.com/recipes/steamed-artichokes-with-green-garlic-aioli-11704
# recipe link:  http://www.chowhound.com/recipes/green-bean-tomato-and-shallot-salad-10463
# recipe link:  http://www.chowhound.com/recipes/marshmallow-frosting-30784
# recipe link:  http://www.chowhound.com/recipes/baked-apricot-chicken-30782
# recipe link:  http://www.chowhound.com/recipes/kale-and-parmesan-egg-drop-soup-stracciatella-30659
# recipe link:  http://www.chowhound.com/recipes/red-wine-braised-beef-with-apple-gremolata-30866
# recipe link:  http://www.chowhound.com/recipes/bobbing-for-mezcal-30837
# recipe link:  http://www.chowhound.com/recipes/grilled-flatbread-with-potato-chevre-and-herbs-30763
# recipe link:  http://www.chowhound.com/recipes/frozen-pineapple-daiquiri-30751
# recipe link:  http://www.chowhound.com/recipes/swiss-chard-with-lentils-and-feta-cheese-30566
# recipe link:  http://www.chowhound.com/recipes/braised-white-beans-with-chard-14157
# recipe link:  http://www.chowhound.com/recipes/honey-butter-30739
# recipe link:  http://www.chowhound.com/recipes/remoulade-10611
# recipe link:  http://www.chowhound.com/recipes/orange-honey-mustard-baked-chicken-breasts-30560
# recipe link:  http://www.chowhound.com/recipes/chicken-fried-steak-with-country-gravy-30674
# recipe link:  http://www.chowhound.com/recipes/virgin-pimms-cup-30601
# recipe link:  http://www.chowhound.com/recipes/mouth-blistering-habanero-carrot-hot-sauce-30756
# recipe link:  http://www.chowhound.com/recipes/smoked-paprika-prosciutto-wrapped-shrimp-13439
# recipe link:  http://www.chowhound.com/recipes/the-red-howler-hot-sauce-30790
# recipe link:  http://www.chowhound.com/recipes/chocolate-pound-cake-30894
# recipe link:  http://www.chowhound.com/recipes/panzanella-tuscan-bread-salad-10638
# recipe link:  http://www.chowhound.com/recipes/sesame-shrimp-with-cilantro-lime-sauce-10466
# recipe link:  http://www.chowhound.com/recipes/creamy-mushroom-gravy-30890
# recipe link:  http://www.chowhound.com/recipes/bacon-cheeseburger-30731
# recipe link:  http://www.chowhound.com/recipes/beer-braised-bratwursts-with-onion-14145
# recipe link:  http://www.chowhound.com/recipes/mustard-greens-salad-with-anchovy-dressing-30882
# recipe link:  http://www.chowhound.com/recipes/slow-cooker-ranch-style-pinto-beans-30795
# recipe link:  http://www.chowhound.com/recipes/loaded-baked-potato-soup-30857
# recipe link:  http://www.chowhound.com/recipes/black-sesame-and-mustard-popcorn-10863
# recipe link:  http://www.chowhound.com/recipes/beef-and-vegetable-shish-kebabs-30716
# recipe link:  http://www.chowhound.com/recipes/steak-and-eggs-benedict-with-bearnaise-sauce-30712
# recipe link:  http://www.chowhound.com/recipes/habanero-orange-stomach-punch-30791
# recipe link:  http://www.chowhound.com/recipes/virgin-gin-and-tonic-30599
# recipe link:  http://www.chowhound.com/recipes/marinated-bocconcini-10957
# recipe link:  http://www.chowhound.com/recipes/apple-brandy-hot-toddy-11417
# recipe link:  http://www.chowhound.com/recipes/crispy-prosciutto-wrapped-asparagus-30697
# recipe link:  http://www.chowhound.com/recipes/corn-bell-pepper-and-zucchini-saute-30752
# recipe link:  http://www.chowhound.com/recipes/grilled-buffalo-chicken-sliders-30800
# recipe link:  http://www.chowhound.com/recipes/adobo-marinated-chicken-tacos-30679
# recipe link:  http://www.chowhound.com/recipes/pesto-chicken-and-white-bean-soup-30660
# recipe link:  http://www.chowhound.com/recipes/rice-pilaf-30687
# recipe link:  http://www.chowhound.com/recipes/mint-syrup-10492
# recipe link:  http://www.chowhound.com/recipes/dark-n-stormy-10685
# recipe link:  http://www.chowhound.com/recipes/mr-smokys-chipotle-mustard-hot-sauce-30757
# recipe link:  http://www.chowhound.com/recipes/eggplant-pepper-tomato-sauce-10960
# recipe link:  http://www.chowhound.com/recipes/vegan-quinoa-stuffed-grilled-zucchini-30765
# recipe link:  http://www.chowhound.com/recipes/butterflied-roasted-turkey-with-butternut-squash-stuffing-30874
# recipe link:  http://www.chowhound.com/recipes/zesty-lime-and-ginger-winter-fruit-salad-30565
# recipe link:  http://www.chowhound.com/recipes/slow-cooker-steel-cut-oatmeal-30656
# recipe link:  http://www.chowhound.com/recipes/strawberry-syrup-10708
# recipe link:  http://www.chowhound.com/recipes/italian-fennel-and-turkey-sausage-stuffing-30872
# recipe link:  http://www.chowhound.com/recipes/easy-blender-hollandaise-sauce-30699
# recipe link:  http://www.chowhound.com/recipes/harvest-bowl-punch-30604
# recipe link:  http://www.chowhound.com/recipes/lemon-garlic-vinaigrette-10659
# recipe link:  http://www.chowhound.com/recipes/vegetarian-butternut-squash-and-swiss-chard-polenta-lasagna-30881
# recipe link:  http://www.chowhound.com/recipes/roasted-rosemary-and-lemon-chicken-10530
# recipe link:  http://www.chowhound.com/recipes/cabbage-and-carrot-herbed-slaw-27786
# recipe link:  http://www.chowhound.com/recipes/herbed-potato-salad-30737
# recipe link:  http://www.chowhound.com/recipes/pickled-radish-and-sweet-butter-tea-sandwiches-10911
# recipe link:  http://www.chowhound.com/recipes/asparagus-benedict-with-chevre-dijon-sauce-30714
# recipe link:  http://www.chowhound.com/recipes/easy-spinach-dal-dhal-dhall-30683
# recipe link:  http://www.chowhound.com/recipes/jicama-mango-salsa-30715
# recipe link:  http://www.chowhound.com/recipes/breakfast-sandwich-with-pesto-scrambled-eggs-and-crispy-pancetta-30811
# recipe link:  http://www.chowhound.com/recipes/bourbon-bacon-bbq-chicken-30718
# recipe link:  http://www.chowhound.com/recipes/dijon-vinaigrette-10661
# recipe link:  http://www.chowhound.com/recipes/kumquat-caipirinha-11819
# recipe link:  http://www.chowhound.com/recipes/roasted-brussels-sprouts-with-almonds-and-pecorino-30815
# recipe link:  http://www.chowhound.com/recipes/seared-scallops-with-lemony-farro-and-arugula-salad-30684
# recipe link:  http://www.chowhound.com/recipes/la-pinela-11040
# recipe link:  http://www.chowhound.com/recipes/pumpkin-pie-ice-cream-30889
# recipe link:  http://www.chowhound.com/recipes/chocolate-cheesecake-bars-30802
# recipe link:  http://www.chowhound.com/recipes/gefilte-fish-29535
# recipe link:  http://www.chowhound.com/recipes/black-bottom-cupcakes-30779
# recipe link:  http://www.chowhound.com/recipes/italian-tuna-and-rice-salad-30760
# recipe link:  http://www.chowhound.com/recipes/spinach-pesto-fusilli-30887
# recipe link:  http://www.chowhound.com/recipes/almost-arnie-10438
# recipe link:  http://www.chowhound.com/recipes/spicy-chicken-and-chile-taco-dip-30626
# recipe link:  http://www.chowhound.com/recipes/chocolate-cupcakes-with-peanut-butter-frosting-30830
# recipe link:  http://www.chowhound.com/recipes/the-corsican-11268
# recipe link:  http://www.chowhound.com/recipes/sloppy-joes-30708
# recipe link:  http://www.chowhound.com/recipes/crab-benedict-on-lemon-chive-biscuits-30713
# recipe link:  http://www.chowhound.com/recipes/cornmeal-fried-catfish-with-remoulade-10823
# recipe link:  http://www.chowhound.com/recipes/ratatouille-30806
# recipe link:  http://www.chowhound.com/recipes/tea-and-whiskey-highball-10538
# recipe link:  http://www.chowhound.com/recipes/black-cod-fish-cakes-with-tartar-sauce-21389
# recipe link:  http://www.chowhound.com/recipes/homemade-coffee-liqueur-30897
# recipe link:  http://www.chowhound.com/recipes/bulgur-pilaf-with-roasted-carrots-and-parsnips-30843
# recipe link:  http://www.chowhound.com/recipes/coffee-rubbed-grilled-pork-tenderloin-30746
# recipe link:  http://www.chowhound.com/recipes/tangy-bourbon-bbq-chicken-30720
# recipe link:  http://www.chowhound.com/recipes/log-cabin-13515
# recipe link:  http://www.chowhound.com/recipes/whole-wheat-margherita-pizza-30774
# recipe link:  http://www.chowhound.com/recipes/whole-wheat-pizza-dough-30657
# recipe link:  http://www.chowhound.com/recipes/beef-bourguignon-30817
# recipe link:  http://www.chowhound.com/recipes/buffalo-chicken-dip-30625
# recipe link:  http://www.chowhound.com/recipes/cream-cheese-frosting-30783
# recipe link:  http://www.chowhound.com/recipes/easy-chocolate-sheet-cake-with-mocha-buttercream-frosting-30818
# recipe link:  http://www.chowhound.com/recipes/peach-bellini-30754
# recipe link:  http://www.chowhound.com/recipes/adobo-marinated-bbq-chicken-30717
# recipe link:  http://www.chowhound.com/recipes/baked-eggs-in-stuffing-cups-30891
# recipe link:  http://www.chowhound.com/recipes/lemon-cupcakes-with-lemon-cream-cheese-frosting-30812
# recipe link:  http://www.chowhound.com/recipes/vegetarian-stuffed-red-bell-peppers-30769
# recipe link:  http://www.chowhound.com/recipes/cream-scones-10918
# recipe link:  http://www.chowhound.com/recipes/fast-lemon-parsley-shrimp-pasta-30703
# recipe link:  http://www.chowhound.com/recipes/balsamic-vinaigrette-30726
# recipe link:  http://www.chowhound.com/recipes/french-lentil-terrine-with-savory-carrot-custard-30695
# recipe link:  http://www.chowhound.com/recipes/cranberry-shortbread-bars-with-almond-streusel-30895
# recipe link:  http://www.chowhound.com/recipes/monkey-bread-pluckets-30689
# recipe link:  http://www.chowhound.com/recipes/bacon-jam-30801
# recipe link:  http://www.chowhound.com/recipes/smoky-sweet-bbq-beef-short-ribs-30742
# recipe link:  http://www.chowhound.com/recipes/diy-conversation-heart-candy-30666
# recipe link:  http://www.chowhound.com/recipes/jalapeno-cornbread-muffins-30870
# recipe link:  http://www.chowhound.com/recipes/warm-cheesy-bean-dip-30799
# recipe link:  http://www.chowhound.com/recipes/creamy-cucumber-salad-30781
# recipe link:  http://www.chowhound.com/recipes/easy-slow-cooker-bbq-beef-brisket-30796
# recipe link:  http://www.chowhound.com/recipes/chicken-a-la-king-30707
# recipe link:  http://www.chowhound.com/recipes/smoked-salmon-and-mozzarella-calzone-10956
# recipe link:  http://www.chowhound.com/recipes/kiwi-sparkler-30564
# recipe link:  http://www.chowhound.com/recipes/the-crushed-grape-30836
# recipe link:  http://www.chowhound.com/recipes/beefy-macaroni-casserole-30861
# recipe link:  http://www.chowhound.com/recipes/lotsa-serranos-blazing-hot-sauce-30758
# recipe link:  http://www.chowhound.com/recipes/slow-cooker-collard-greens-30794
# recipe link:  http://www.chowhound.com/recipes/martinique-11267
# recipe link:  http://www.chowhound.com/recipes/grilled-salmon-with-lemon-pepper-compound-butter-30727
# recipe link:  http://www.chowhound.com/recipes/concord-grape-martini-10880
# recipe link:  http://www.chowhound.com/recipes/blackberry-orange-muffins-30777
# recipe link:  http://www.chowhound.com/recipes/cherry-bomb-hot-sauce-30789
# recipe link:  http://www.chowhound.com/recipes/yellow-bicycle-14331
# recipe link:  http://www.chowhound.com/recipes/coffee-flip-30896
# recipe link:  http://www.chowhound.com/recipes/mulled-hard-pear-cider-14574
# recipe link:  http://www.chowhound.com/recipes/romesco-sauce-30559
# recipe link:  http://www.chowhound.com/recipes/stir-fried-tamarind-eggplant-30753
# recipe link:  http://www.chowhound.com/recipes/pan-seared-halibut-with-wine-braised-leeks-30900
# recipe link:  http://www.chowhound.com/recipes/blood-orange-vinaigrette-11389
# recipe link:  http://www.chowhound.com/recipes/oven-fried-buttermilk-chicken-11801
# recipe link:  http://www.chowhound.com/recipes/turkey-waldorf-salad-30876
# recipe link:  http://www.chowhound.com/recipes/passover-orange-angel-food-cake-with-strawberries-18660
# recipe link:  http://www.chowhound.com/recipes/cocoa-chile-rubbed-grilled-pork-tenderloin-30745
# recipe link:  http://www.chowhound.com/recipes/black-forest-cake-30863
# recipe link:  http://www.chowhound.com/recipes/pate-a-choux-shells-french-pastry-shells-30867
# recipe link:  http://www.chowhound.com/recipes/velvetbomb-punch-30688
# recipe link:  http://www.chowhound.com/recipes/rib-steaks-with-spice-rub-and-green-bean-salad-10499
# recipe link:  http://www.chowhound.com/recipes/grilled-greek-salad-10924
# recipe link:  http://www.chowhound.com/recipes/vietnamese-lamb-chops-30858
# recipe link:  http://www.chowhound.com/recipes/slow-cooker-chicken-chile-verde-30792
# recipe link:  http://www.chowhound.com/recipes/creamy-rigatoni-with-chicken-and-mushrooms-30671
# recipe link:  http://www.chowhound.com/recipes/cocktail-sauce-30864
# recipe link:  http://www.chowhound.com/recipes/grilled-pork-chops-with-fresh-plum-sauce-30776
# recipe link:  http://www.chowhound.com/recipes/roasted-banana-nutella-quick-bread-30562
# recipe link:  http://www.chowhound.com/recipes/chicken-piccata-30709
# recipe link:  http://www.chowhound.com/recipes/greek-pasta-with-shrimp-feta-tomatoes-and-olives-30670
# recipe link:  http://www.chowhound.com/recipes/tangy-southwestern-dressing-30440
# recipe link:  http://www.chowhound.com/recipes/peanut-butter-honey-banana-bread-30738
# recipe link:  http://www.chowhound.com/recipes/smoky-grilled-shrimp-with-marie-rose-sauce-30775
# recipe link:  http://www.chowhound.com/recipes/brown-butter-hasselback-potatoes-accordion-potatoes-30888
# recipe link:  http://www.chowhound.com/recipes/easy-raspberry-tart-30778
# recipe link:  http://www.chowhound.com/recipes/pistachio-shortbread-10917
# recipe link:  http://www.chowhound.com/recipes/tamarind-caipirinha-30771
# recipe link:  http://www.chowhound.com/recipes/slow-cooker-chicken-soup-30868
# recipe link:  http://www.chowhound.com/recipes/lemon-chive-biscuits-30730
# recipe link:  http://www.chowhound.com/recipes/vinegar-and-spice-oven-ribs-25638
# recipe link:  http://www.chowhound.com/recipes/mexican-turkey-meatball-soup-30658
# recipe link:  http://www.chowhound.com/recipes/bread-and-butter-radishes-10909
# recipe link:  http://www.chowhound.com/recipes/roasted-cauliflower-with-crispy-breadcrumbs-and-golden-raisins-30563
# recipe link:  http://www.chowhound.com/recipes/melon-and-cucumber-salad-with-feta-black-pepper-and-mint-30734
# recipe link:  http://www.chowhound.com/recipes/basic-seared-salmon-fillet-30847
# recipe link:  http://www.chowhound.com/recipes/warm-quinoa-salad-with-roasted-autumn-vegetables-and-ginger-scallion-dressing-30814
# recipe link:  http://www.chowhound.com/recipes/st-cecilias-punch-30605
# recipe link:  http://www.chowhound.com/recipes/baked-cracker-crusted-chicken-fingers-27464
# recipe link:  http://www.chowhound.com/recipes/watermelon-juice-with-fleur-de-sel-10582
# recipe link:  http://www.chowhound.com/recipes/chocolate-cupcakes-with-toasted-marshmallow-frosting-30680
# recipe link:  http://www.chowhound.com/recipes/pepperoni-pizza-dip-30624
# recipe link:  http://www.chowhound.com/recipes/marie-rose-sauce-30860
# recipe link:  http://www.chowhound.com/recipes/virgin-negroni-30600
# recipe link:  http://www.chowhound.com/recipes/classic-eggs-benedict-30711
# recipe link:  http://www.chowhound.com/recipes/maple-mashed-sweet-potatoes-30871
# recipe link:  http://www.chowhound.com/recipes/shredded-kale-tomatoes-feta-and-mint-salad-30733
# recipe link:  http://www.chowhound.com/recipes/shallot-tarragon-jam-10757
# recipe link:  http://www.chowhound.com/recipes/meyer-lemon-and-black-pepper-cookies-10792
# recipe link:  http://www.chowhound.com/recipes/german-chocolate-cake-13745
# recipe link:  http://www.chowhound.com/recipes/apple-cinnamon-waffles-30885
# recipe link:  http://www.chowhound.com/recipes/crumbly-oat-and-apricot-bars-10920
# recipe link:  http://www.chowhound.com/recipes/bbq-chicken-pizza-30744
# recipe link:  http://www.chowhound.com/recipes/basic-steamed-artichokes-28693
# recipe link:  http://www.chowhound.com/recipes/balsamic-marinated-grilled-flank-steak-with-bell-pepper-relish-30725
# recipe link:  http://www.chowhound.com/recipes/hugging-thyme-11122
# recipe link:  http://www.chowhound.com/recipes/prosciutto-palmiers-10515
# recipe link:  http://www.chowhound.com/recipes/herb-crusted-rack-of-lamb-30702
# recipe link:  http://www.chowhound.com/recipes/tangy-cabbage-slaw-30732
# recipe link:  http://www.chowhound.com/recipes/spiked-coffee-with-pumpkin-spice-30898
# recipe link:  http://www.chowhound.com/recipes/semolina-onion-rings-30878
# recipe link:  http://www.chowhound.com/recipes/the-flying-fig-11113
# recipe link:  http://www.chowhound.com/recipes/grand-marnier-tea-cooler-10459
# recipe link:  http://www.chowhound.com/recipes/dill-chickpea-and-feta-pasta-salad-30740
# recipe link:  http://www.chowhound.com/recipes/creme-fraiche-whipped-cream-30827
# recipe link:  http://www.chowhound.com/recipes/chicken-breasts-stuffed-with-prosciutto-and-gruyere-cheese-chicken-cordon-bleu-30678
# recipe link:  http://www.chowhound.com/recipes/honey-whole-wheat-dinner-rolls-30883
# recipe link:  http://www.chowhound.com/recipes/watermelon-lemonade-10549
# recipe link:  http://www.chowhound.com/recipes/pork-chops-with-cherry-sauce-11958
# recipe link:  http://www.chowhound.com/recipes/sweet-soy-glazed-bbq-chicken-30719
# recipe link:  http://www.chowhound.com/recipes/fresh-tomato-basil-martini-30770
# recipe link:  http://www.chowhound.com/recipes/spiced-brandy-pear-punch-30838
# recipe link:  http://www.chowhound.com/recipes/pasta-with-broccoli-crispy-prosciutto-and-toasted-breadcrumbs-10978
# recipe link:  http://www.chowhound.com/recipes/creamy-peppercorn-dressing-27710
# recipe link:  http://www.chowhound.com/recipes/basic-whole-roasted-chicken-30264
# recipe link:  http://www.chowhound.com/recipes/cucumber-hummus-and-lemon-tea-sandwiches-10915
# recipe link:  http://www.chowhound.com/recipes/pollo-alla-valdostana-chicken-with-proscuitto-and-fontina-cheese-10753
# recipe link:  http://www.chowhound.com/recipes/charles-chocolates-bittersweet-chocolate-truffles-10656
# recipe link:  http://www.chowhound.com/recipes/napa-cabbage-and-udon-miso-soup-30561
# recipe link:  http://www.chowhound.com/recipes/charred-okra-with-bacon-jam-30780
# recipe link:  http://www.chowhound.com/recipes/buttermilk-panna-cotta-30807
# recipe link:  http://www.chowhound.com/recipes/parmigianoblack-pepper-popcorn-10862
# recipe link:  http://www.chowhound.com/recipes/smoked-and-steamed-salmon-rillettes-30693
# recipe link:  http://www.chowhound.com/recipes/watermelon-margarita-30705
# recipe link:  http://www.chowhound.com/recipes/butterscotch-pecan-blondies-30804
# recipe link:  http://www.chowhound.com/recipes/peanut-butter-and-jelly-bars-30803
# recipe link:  http://www.chowhound.com/recipes/peach-pie-with-pecan-streusel-30755
# recipe link:  http://www.chowhound.com/recipes/ruby-on-rails-10707
# recipe link:  http://www.chowhound.com/recipes/potato-salad-with-peas-and-mint-11798
# recipe link:  http://www.chowhound.com/recipes/short-ribs-with-frisee-parsley-salad-10473
# recipe link:  http://www.chowhound.com/recipes/spaghetti-squash-cakes-30845
# recipe link:  http://www.chowhound.com/recipes/mustard-roasted-potatoes-30873
# recipe link:  http://www.chowhound.com/recipes/slow-cooker-rice-pudding-30793
# recipe link:  http://www.chowhound.com/recipes/stuffed-poblanos-with-black-beans-and-cheese-10921
# recipe link:  http://www.chowhound.com/recipes/fresh-spinach-dip-30667
# recipe link:  http://www.chowhound.com/recipes/tangy-cucumber-pickles-ah-jaht-30748
# recipe link:  http://www.chowhound.com/recipes/cardinal-punch-30603
# recipe link:  http://www.chowhound.com/recipes/white-russian-rice-cereal-treats-30865
# recipe link:  http://www.chowhound.com/recipes/chocolate-fondue-30661
# recipe link:  http://www.chowhound.com/recipes/pineapple-rum-sorbet-30761
# recipe link:  http://www.chowhound.com/recipes/vanilla-buttercream-frosting-13728
# recipe link:  http://www.chowhound.com/recipes/blt-scrambled-eggs-30809
# recipe link:  http://www.chowhound.com/recipes/pasta-carbonara-with-peas-10652
# recipe link:  http://www.chowhound.com/recipes/strawberry-blueberry-crisp-baked-in-a-jar-30694
# recipe link:  http://www.chowhound.com/recipes/strawberry-rhubarb-pie-with-sour-cream-crust-30700
# recipe link:  http://www.chowhound.com/recipes/orange-angel-food-cake-with-strawberries-18898
# recipe link:  http://www.chowhound.com/recipes/grilled-tofu-torta-30764
# recipe link:  http://www.chowhound.com/recipes/portobello-mushrooms-stuffed-with-french-onion-soup-30886
# recipe link:  http://www.chowhound.com/recipes/fresh-herb-and-cream-cheese-scramble-30808
# recipe link:  http://www.chowhound.com/recipes/dill-dip-30797
# recipe link:  http://www.chowhound.com/recipes/homemade-pumpkin-spice-liqueur-30899
# recipe link:  http://www.chowhound.com/recipes/orecchiette-with-chorizo-and-swiss-chard-30821
# recipe link:  http://www.chowhound.com/recipes/celery-margarita-30704
# recipe link:  http://www.chowhound.com/recipes/cinnamon-syrup-11046
# recipe link:  http://www.chowhound.com/recipes/oregano-marinade-10923
# recipe link:  http://www.chowhound.com/recipes/summer-corn-chowder-30772
# recipe link:  http://www.chowhound.com/recipes/hibiscus-margarita-30706
# recipe link:  http://www.chowhound.com/recipes/chicken-satay-with-spicy-peanut-sauce-30747
# recipe link:  http://www.chowhound.com/recipes/rhubarb-and-strawberry-compote-10903
# recipe link:  http://www.chowhound.com/recipes/chocolate-swirl-pumpkin-bread-30862
# recipe link:  http://www.chowhound.com/recipes/milk-chocolate-buttercream-30785
# recipe link:  http://www.chowhound.com/recipes/easy-glazed-carrots-30696
# recipe link:  http://www.chowhound.com/recipes/breakfast-bruschetta-with-fontina-scrambled-eggs-and-salami-30810
# recipe link:  http://www.chowhound.com/recipes/strawberry-shortcakes-30672
# recipe link:  http://www.chowhound.com/recipes/grilled-halloumi-and-vegetable-kebabs-30768
# recipe link:  http://www.chowhound.com/recipes/shrimp-cocktail-30813
# recipe link:  http://www.chowhound.com/recipes/bow-tie-pasta-with-corn-thyme-and-parmesan-30773

# %%
cuisine_dataframe
# Out:
#                                           recipe_title  cuisine  num_recipes  \
# 0                          Adobo-Marinated BBQ Chicken  Unknown         6318
# 1                        Adobo-Marinated Chicken Tacos  Unknown         6318
# 2                                         Almost Arnie  Unknown         6318
# 3                               Apple Brandy Hot Toddy  Unknown         6318
# 4                               Apple-Cinnamon Waffles  Unknown         6318
# 5           Asparagus Benedict with Chèvre-Dijon Sauce  Unknown         6318
# 6                                    BBQ Chicken Pizza  Unknown         6318
# 7                                   BLT Scrambled Eggs  Unknown         6318
# 8                                   Bacon Cheeseburger  Unknown         6318
# 9                                            Bacon Jam  Unknown         6318
# 10                               Baked Apricot Chicken  Unknown         6318
# 11               Baked Cracker-Crusted Chicken Fingers  Unknown         6318
# 12                         Baked Eggs in Stuffing Cups  Unknown         6318
# 13                                Balsamic Vinaigrette  Unknown         6318
# 14   Balsamic-Marinated Grilled Flank Steak with Be...  Unknown         6318
# 15                          Basic Seared Salmon Fillet  Unknown         6318
# 16                            Basic Steamed Artichokes  Unknown         6318
# 17                         Basic Whole Roasted Chicken  Unknown         6318
# 18                                    Beef Bourguignon  Unknown         6318
# 19                     Beef and Vegetable Shish Kebabs  Unknown         6318
# 20                            Beefy Macaroni Casserole  Unknown         6318
# 21                  Beer-Braised Bratwursts with Onion  Unknown         6318
# 22                               Black Bottom Cupcakes  Unknown         6318
# 23              Black Cod Fish Cakes with Tartar Sauce  Unknown         6318
# 24                                   Black Forest Cake  Unknown         6318
# 25                    Black Sesame and Mustard Popcorn  Unknown         6318
# 26                           Blackberry-Orange Muffins  Unknown         6318
# 27                            Blood Orange Vinaigrette  Unknown         6318
# 28                                  Bobbing for Mezcal  Unknown         6318
# 29                           Bourbon-Bacon BBQ Chicken  Unknown         6318
# ..                                                 ...      ...          ...
# 240                        Tangy Southwestern Dressing  Unknown         6318
# 241                             Tarragon Chicken Salad  Unknown         6318
# 242                           Tea and Whiskey Highball  Unknown         6318
# 243                              The Corsican Cocktail  Unknown         6318
# 244                                  The Crushed Grape  Unknown         6318
# 245                                     The Flying Fig  Unknown         6318
# 246                           The Red Howler Hot Sauce  Unknown         6318
# 247                          The Sweeter Welcome Punch  Unknown         6318
# 248                               Turkey Waldorf Salad  Unknown         6318
# 249                       Vanilla Buttercream Frosting  Unknown         6318
# 250              Vegan Quinoa-Stuffed Grilled Zucchini  Unknown         6318
# 251  Vegetarian Butternut Squash and Swiss Chard Po...  Unknown         6318
# 252                Vegetarian Stuffed Red Bell Peppers  Unknown         6318
# 253                                   Velvetbomb Punch  Unknown         6318
# 254                              Vietnamese Lamb Chops  Unknown         6318
# 255                  Vinegar and Spice Oven-Baked Ribs  Unknown         6318
# 256                               Virgin Gin and Tonic  Unknown         6318
# 257                                     Virgin Negroni  Unknown         6318
# 258                                  Virgin Pimm's Cup  Unknown         6318
# 259                               Warm Cheesy Bean Dip  Unknown         6318
# 260  Warm Quinoa Salad with Roasted Autumn Vegetabl...  Unknown         6318
# 261    Warm, Cheesy Swiss Chard and Roasted Garlic Dip  Unknown         6318
# 262                 Watermelon Juice with Fleur de Sel  Unknown         6318
# 263                       Watermelon Lemonade Cocktail  Unknown         6318
# 264                               Watermelon Margarita  Unknown         6318
# 265                   White Russian Rice Cereal Treats  Unknown         6318
# 266                       Whole Wheat Margherita Pizza  Unknown         6318
# 267                            Whole Wheat Pizza Dough  Unknown         6318
# 268                                     Yellow Bicycle  Unknown         6318
# 269           Zesty Lime and Ginger Winter Fruit Salad  Unknown         6318
#
#      pages                                    recipes_details     source
# 0      234  {u'total_time': u'1 hr 30 mins', u'active_time...  Chowhound
# 1      234  {u'total_time': u'1 hr, plus marinating time',...  Chowhound
# 2      234  {u'total_time': u'Under 5 mins', u'active_time...  Chowhound
# 3      234  {u'total_time': u'Under 5 mins', u'active_time...  Chowhound
# 4      234  {u'total_time': u'55 mins', u'active_time': No...  Chowhound
# 5      234  {u'total_time': u'50 mins', u'active_time': No...  Chowhound
# 6      234  {u'total_time': u'2 hrs 15 mins', u'active_tim...  Chowhound
# 7      234  {u'total_time': u'40 mins', u'active_time': No...  Chowhound
# 8      234  {u'total_time': u'45 mins', u'active_time': No...  Chowhound
# 9      234  {u'total_time': u'55 mins', u'active_time': No...  Chowhound
# 10     234  {u'total_time': u'2 hrs 10 mins', u'active_tim...  Chowhound
# 11     234  {u'total_time': u'35 mins', u'active_time': No...  Chowhound
# 12     234  {u'total_time': u'50 mins', u'active_time': No...  Chowhound
# 13     234  {u'total_time': u'5 mins', u'active_time': Non...  Chowhound
# 14     234  {u'total_time': u'1 hr 15 mins', u'active_time...  Chowhound
# 15     234  {u'total_time': u'15 mins', u'active_time': No...  Chowhound
# 16     234  {u'total_time': u'About 30 mins', u'active_tim...  Chowhound
# 17     234  {u'total_time': u'1 hr 45 mins', u'active_time...  Chowhound
# 18     234  {u'total_time': u'3 hrs 15 mins', u'active_tim...  Chowhound
# 19     234  {u'total_time': u'1 hr 10 mins', u'active_time...  Chowhound
# 20     234  {u'total_time': u'1 hr 25 mins', u'active_time...  Chowhound
# 21     234  {u'total_time': u'1 hr 50 mins', u'active_time...  Chowhound
# 22     234  {u'total_time': u'1 hr 15 mins, plus cooling t...  Chowhound
# 23     234  {u'total_time': u'40 mins', u'active_time': No...  Chowhound
# 24     234  {u'total_time': u'3 hrs 20 mins', u'active_tim...  Chowhound
# 25     234  {u'total_time': u'10 mins', u'active_time': No...  Chowhound
# 26     234  {u'total_time': u'55 mins', u'active_time': No...  Chowhound
# 27     234  {u'total_time': u'10 mins', u'active_time': No...  Chowhound
# 28     234  {u'total_time': u'Under 5 mins', u'active_time...  Chowhound
# 29     234  {u'total_time': u'1 hr 30 mins', u'active_time...  Chowhound
# ..     ...                                                ...        ...
# 240    234  {u'total_time': u'15 mins', u'active_time': No...  Chowhound
# 241    234  {u'total_time': u'1 hr 20 mins, plus 1 hr chil...  Chowhound
# 242    234  {u'total_time': u'30 mins, plus 3 hrs chilling...  Chowhound
# 243    234  {u'total_time': u'Under 5 mins', u'active_time...  Chowhound
# 244    234  {u'total_time': u'Under 5 mins', u'active_time...  Chowhound
# 245    234  {u'total_time': u'Under 5 mins', u'active_time...  Chowhound
# 246    234  {u'total_time': u'20 mins, plus 24 hrs aging t...  Chowhound
# 247    234  {u'total_time': u'10 mins', u'active_time': u'...  Chowhound
# 248    234  {u'total_time': u'30 mins', u'active_time': No...  Chowhound
# 249    234  {u'total_time': u'5 mins', u'active_time': Non...  Chowhound
# 250    234  {u'total_time': u'1 hr 20 mins, plus 2 hrs cas...  Chowhound
# 251    234  {u'total_time': u'2 hrs 30 mins', u'active_tim...  Chowhound
# 252    234  {u'total_time': u'1 hr 30 mins', u'active_time...  Chowhound
# 253    234  {u'total_time': u'10 mins, plus 10 hrs freezin...  Chowhound
# 254    234  {u'total_time': u'1 hr, plus at least 4 hrs ma...  Chowhound
# 255    234  {u'total_time': u'2 hrs 35 mins, plus at least...  Chowhound
# 256    234  {u'total_time': u'10 mins, plus at least 3 hrs...  Chowhound
# 257    234  {u'total_time': u'10 mins, plus 3 hrs infusing...  Chowhound
# 258    234  {u'total_time': u'15 mins, plus 3 hrs infusing...  Chowhound
# 259    234  {u'total_time': u'40 mins', u'active_time': u'...  Chowhound
# 260    234  {u'total_time': u'45 mins', u'active_time': No...  Chowhound
# 261    234  {u'total_time': u'1 hr 45 mins', u'active_time...  Chowhound
# 262    234  {u'total_time': u'10 mins, plus 1 hr 30 mins c...  Chowhound
# 263    234  {u'total_time': u'15 mins, plus 2 hrs chilling...  Chowhound
# 264    234  {u'total_time': u'15 mins, plus 1 hr 30 mins c...  Chowhound
# 265    234  {u'total_time': u'1 hr', u'active_time': None,...  Chowhound
# 266    234  {u'total_time': u'2 hr 30 mins', u'active_time...  Chowhound
# 267    234  {u'total_time': u'30 mins, plus 1 hr 20 mins r...  Chowhound
# 268    234  {u'total_time': u'Under 5 mins', u'active_time...  Chowhound
# 269    234  {u'total_time': u'35 mins', u'active_time': No...  Chowhound
#
# [270 rows x 6 columns]

# %%
cuisine_dataframe.reset_index(inplace=True)

# %%
cuisine_dataframe.rename(columns={'index': 'recipe_title'}, inplace=True)

# %%
cuisine_dataframe.to_csv("recipes_data_Chowhound_31-40.csv", encoding='UTF-8')

# %%
cuisine_dataframe
# Out:
#                                           recipe_title  cuisine  num_recipes  \
# 0                          Adobo-Marinated BBQ Chicken  Unknown         6318
# 1                        Adobo-Marinated Chicken Tacos  Unknown         6318
# 2                                         Almost Arnie  Unknown         6318
# 3                               Apple Brandy Hot Toddy  Unknown         6318
# 4                               Apple-Cinnamon Waffles  Unknown         6318
# 5           Asparagus Benedict with Chèvre-Dijon Sauce  Unknown         6318
# 6                                    BBQ Chicken Pizza  Unknown         6318
# 7                                   BLT Scrambled Eggs  Unknown         6318
# 8                                   Bacon Cheeseburger  Unknown         6318
# 9                                            Bacon Jam  Unknown         6318
# 10                               Baked Apricot Chicken  Unknown         6318
# 11               Baked Cracker-Crusted Chicken Fingers  Unknown         6318
# 12                         Baked Eggs in Stuffing Cups  Unknown         6318
# 13                                Balsamic Vinaigrette  Unknown         6318
# 14   Balsamic-Marinated Grilled Flank Steak with Be...  Unknown         6318
# 15                          Basic Seared Salmon Fillet  Unknown         6318
# 16                            Basic Steamed Artichokes  Unknown         6318
# 17                         Basic Whole Roasted Chicken  Unknown         6318
# 18                                    Beef Bourguignon  Unknown         6318
# 19                     Beef and Vegetable Shish Kebabs  Unknown         6318
# 20                            Beefy Macaroni Casserole  Unknown         6318
# 21                  Beer-Braised Bratwursts with Onion  Unknown         6318
# 22                               Black Bottom Cupcakes  Unknown         6318
# 23              Black Cod Fish Cakes with Tartar Sauce  Unknown         6318
# 24                                   Black Forest Cake  Unknown         6318
# 25                    Black Sesame and Mustard Popcorn  Unknown         6318
# 26                           Blackberry-Orange Muffins  Unknown         6318
# 27                            Blood Orange Vinaigrette  Unknown         6318
# 28                                  Bobbing for Mezcal  Unknown         6318
# 29                           Bourbon-Bacon BBQ Chicken  Unknown         6318
# ..                                                 ...      ...          ...
# 240                        Tangy Southwestern Dressing  Unknown         6318
# 241                             Tarragon Chicken Salad  Unknown         6318
# 242                           Tea and Whiskey Highball  Unknown         6318
# 243                              The Corsican Cocktail  Unknown         6318
# 244                                  The Crushed Grape  Unknown         6318
# 245                                     The Flying Fig  Unknown         6318
# 246                           The Red Howler Hot Sauce  Unknown         6318
# 247                          The Sweeter Welcome Punch  Unknown         6318
# 248                               Turkey Waldorf Salad  Unknown         6318
# 249                       Vanilla Buttercream Frosting  Unknown         6318
# 250              Vegan Quinoa-Stuffed Grilled Zucchini  Unknown         6318
# 251  Vegetarian Butternut Squash and Swiss Chard Po...  Unknown         6318
# 252                Vegetarian Stuffed Red Bell Peppers  Unknown         6318
# 253                                   Velvetbomb Punch  Unknown         6318
# 254                              Vietnamese Lamb Chops  Unknown         6318
# 255                  Vinegar and Spice Oven-Baked Ribs  Unknown         6318
# 256                               Virgin Gin and Tonic  Unknown         6318
# 257                                     Virgin Negroni  Unknown         6318
# 258                                  Virgin Pimm's Cup  Unknown         6318
# 259                               Warm Cheesy Bean Dip  Unknown         6318
# 260  Warm Quinoa Salad with Roasted Autumn Vegetabl...  Unknown         6318
# 261    Warm, Cheesy Swiss Chard and Roasted Garlic Dip  Unknown         6318
# 262                 Watermelon Juice with Fleur de Sel  Unknown         6318
# 263                       Watermelon Lemonade Cocktail  Unknown         6318
# 264                               Watermelon Margarita  Unknown         6318
# 265                   White Russian Rice Cereal Treats  Unknown         6318
# 266                       Whole Wheat Margherita Pizza  Unknown         6318
# 267                            Whole Wheat Pizza Dough  Unknown         6318
# 268                                     Yellow Bicycle  Unknown         6318
# 269           Zesty Lime and Ginger Winter Fruit Salad  Unknown         6318
#
#      pages                                    recipes_details     source
# 0      234  {u'total_time': u'1 hr 30 mins', u'active_time...  Chowhound
# 1      234  {u'total_time': u'1 hr, plus marinating time',...  Chowhound
# 2      234  {u'total_time': u'Under 5 mins', u'active_time...  Chowhound
# 3      234  {u'total_time': u'Under 5 mins', u'active_time...  Chowhound
# 4      234  {u'total_time': u'55 mins', u'active_time': No...  Chowhound
# 5      234  {u'total_time': u'50 mins', u'active_time': No...  Chowhound
# 6      234  {u'total_time': u'2 hrs 15 mins', u'active_tim...  Chowhound
# 7      234  {u'total_time': u'40 mins', u'active_time': No...  Chowhound
# 8      234  {u'total_time': u'45 mins', u'active_time': No...  Chowhound
# 9      234  {u'total_time': u'55 mins', u'active_time': No...  Chowhound
# 10     234  {u'total_time': u'2 hrs 10 mins', u'active_tim...  Chowhound
# 11     234  {u'total_time': u'35 mins', u'active_time': No...  Chowhound
# 12     234  {u'total_time': u'50 mins', u'active_time': No...  Chowhound
# 13     234  {u'total_time': u'5 mins', u'active_time': Non...  Chowhound
# 14     234  {u'total_time': u'1 hr 15 mins', u'active_time...  Chowhound
# 15     234  {u'total_time': u'15 mins', u'active_time': No...  Chowhound
# 16     234  {u'total_time': u'About 30 mins', u'active_tim...  Chowhound
# 17     234  {u'total_time': u'1 hr 45 mins', u'active_time...  Chowhound
# 18     234  {u'total_time': u'3 hrs 15 mins', u'active_tim...  Chowhound
# 19     234  {u'total_time': u'1 hr 10 mins', u'active_time...  Chowhound
# 20     234  {u'total_time': u'1 hr 25 mins', u'active_time...  Chowhound
# 21     234  {u'total_time': u'1 hr 50 mins', u'active_time...  Chowhound
# 22     234  {u'total_time': u'1 hr 15 mins, plus cooling t...  Chowhound
# 23     234  {u'total_time': u'40 mins', u'active_time': No...  Chowhound
# 24     234  {u'total_time': u'3 hrs 20 mins', u'active_tim...  Chowhound
# 25     234  {u'total_time': u'10 mins', u'active_time': No...  Chowhound
# 26     234  {u'total_time': u'55 mins', u'active_time': No...  Chowhound
# 27     234  {u'total_time': u'10 mins', u'active_time': No...  Chowhound
# 28     234  {u'total_time': u'Under 5 mins', u'active_time...  Chowhound
# 29     234  {u'total_time': u'1 hr 30 mins', u'active_time...  Chowhound
# ..     ...                                                ...        ...
# 240    234  {u'total_time': u'15 mins', u'active_time': No...  Chowhound
# 241    234  {u'total_time': u'1 hr 20 mins, plus 1 hr chil...  Chowhound
# 242    234  {u'total_time': u'30 mins, plus 3 hrs chilling...  Chowhound
# 243    234  {u'total_time': u'Under 5 mins', u'active_time...  Chowhound
# 244    234  {u'total_time': u'Under 5 mins', u'active_time...  Chowhound
# 245    234  {u'total_time': u'Under 5 mins', u'active_time...  Chowhound
# 246    234  {u'total_time': u'20 mins, plus 24 hrs aging t...  Chowhound
# 247    234  {u'total_time': u'10 mins', u'active_time': u'...  Chowhound
# 248    234  {u'total_time': u'30 mins', u'active_time': No...  Chowhound
# 249    234  {u'total_time': u'5 mins', u'active_time': Non...  Chowhound
# 250    234  {u'total_time': u'1 hr 20 mins, plus 2 hrs cas...  Chowhound
# 251    234  {u'total_time': u'2 hrs 30 mins', u'active_tim...  Chowhound
# 252    234  {u'total_time': u'1 hr 30 mins', u'active_time...  Chowhound
# 253    234  {u'total_time': u'10 mins, plus 10 hrs freezin...  Chowhound
# 254    234  {u'total_time': u'1 hr, plus at least 4 hrs ma...  Chowhound
# 255    234  {u'total_time': u'2 hrs 35 mins, plus at least...  Chowhound
# 256    234  {u'total_time': u'10 mins, plus at least 3 hrs...  Chowhound
# 257    234  {u'total_time': u'10 mins, plus 3 hrs infusing...  Chowhound
# 258    234  {u'total_time': u'15 mins, plus 3 hrs infusing...  Chowhound
# 259    234  {u'total_time': u'40 mins', u'active_time': u'...  Chowhound
# 260    234  {u'total_time': u'45 mins', u'active_time': No...  Chowhound
# 261    234  {u'total_time': u'1 hr 45 mins', u'active_time...  Chowhound
# 262    234  {u'total_time': u'10 mins, plus 1 hr 30 mins c...  Chowhound
# 263    234  {u'total_time': u'15 mins, plus 2 hrs chilling...  Chowhound
# 264    234  {u'total_time': u'15 mins, plus 1 hr 30 mins c...  Chowhound
# 265    234  {u'total_time': u'1 hr', u'active_time': None,...  Chowhound
# 266    234  {u'total_time': u'2 hr 30 mins', u'active_time...  Chowhound
# 267    234  {u'total_time': u'30 mins, plus 1 hr 20 mins r...  Chowhound
# 268    234  {u'total_time': u'Under 5 mins', u'active_time...  Chowhound
# 269    234  {u'total_time': u'35 mins', u'active_time': No...  Chowhound
#
# [270 rows x 6 columns]

# %% [markdown]
# recipe link:  http://www.chowhound.com/recipes/devils-on-horseback-29172
# {'total_time': u'40 mins', 'active_time': u'\n                20 mins\n              ', 'description': u'We know\u2014wrap pretty much anything in bacon, cook until crisp, and it\u2019s bound to be eaten. This British pub snack, though, with a name that sounds like it\u2019s from some inverted version of the apocalypse, combines salty, crunchy bacon and boozy, sweet plums (a.k.a. prunes). It\u2019s a major crowd-pleaser, and simple to prepare. Steep the dried prunes in an easy syrup of port wine and sugar, then drain (you can do this ahead of time). Wrap a slice of uncooked bacon around each plum and secure with a toothpick. When guests arrive, just pop the prunes in a hot oven and bake until the bacon\u2019s cooked and crispy, the plums hot all the way through. Feel free to experiment, for instance stuff the prunes with blue cheese or toasted walnuts before wrapping.\n\nFor additional appetizer inspiration, check out our Chicken Skewers with Dukkah Crust, Mongolian Beef Kebabs with Chili Jam, and Sesame Shrimp with Cilantro-Lime Sauce.', 'rating': u'5.0', 'nutritional_info': None, 'skill_level': u'Easy', 'ingredient list': [u'30 pitted prunes (about 8 ounces)', u'1 cup tawny port', u'1 tablespoon granulated sugar', u'10 thin slices smoky bacon, cut crosswise into thirds', u'30 toothpicks, soaked in water for at least 15 minutes'], 'preperation steps': [u'1Heat the oven to 500\xb0F and arrange a rack in the middle.', u'2Combine the prunes, port, and sugar in a medium saucepan. Bring to a boil over high heat, stirring until the sugar has dissolved. Reduce the heat to medium low and simmer, stirring occasionally, until the port thickens into a loose syrup, about 15 minutes. Let cool slightly, for about 10 minutes, then drain the prunes of excess syrup or reserve syrup for other uses (for example, serve with seared meats or drizzle into a glass of seltzer or Champagne).', u'3Line a rimmed baking sheet with aluminum foil, then set a cooling rack over the foil.', u'4Wrap a piece of bacon around each prune and secure with a toothpick. Place the prunes at least 1 inch apart on the cooling rack. Bake for 7 minutes, then flip the prunes with tongs and continue to bake until crispy, about 7 to 9 minutes more. Transfer to a paper-towel-lined plate to drain. Cool slightly before serving.'], 'chef': u'Jill Santopietro', 'r_link': 'http://www.chowhound.com/recipes/devils-on-horseback-29172', 'servings': u'30 pieces', 'recipe title': u'Devils on Horseback', 'rating count': u'7', 'image_source': 'http://search.chow.com/thumbnail/320/0/www.chowstatic.com/assets/recipe_photos/29172_devils_horseback.jpg'}
