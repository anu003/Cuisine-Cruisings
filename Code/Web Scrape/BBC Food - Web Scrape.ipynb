# %%
from time import sleep
import requests
from bs4 import BeautifulSoup
import re
from math import ceil
import pandas as pd
from pymongo import MongoClient

# %%
SCRAPING_REQUEST_STAGGER = 2.0 # in seconds
# the main link for BBC food
URL = 'http://www.bbc.co.uk/food/cuisines/'
CUISINE_URL = 'http://www.bbc.co.uk/food/recipes/search?page={}&cuisines%5B0%5D={}&sortBy=lastModified'
RECIPE_URL = 'http://www.bbc.co.uk{}'
NUMBER_OF_RECIPES_PER_PAGE = 15.

# %% [markdown]
# DB_NAME = 'PROJECT_RECIPIES'
# COLLECTION_NAME = 'BBC'
#
# client = MongoClient()
# db = client[DB_NAME]
# coll = db[COLLECTION_NAME]

# %%
def get_content_from_url(link):
    # make request with the input link and return the content of the web link
    sleep(SCRAPING_REQUEST_STAGGER)        
    response = requests.get(link)
    
    # if the status code of response is not 200, then raise a warning
    if response.status_code != 200:
        return False
    return response.content

# %%
def get_number_of_recipes(cuisine):
    # calculate number of recipes for any given cuisine
    
    # create a full link using the cuisine_link and cuisine name to obtain web content from link
    cuisine_link = URL + cuisine
    cuisine_recipes = get_content_from_url(cuisine_link)
    
    # if no content is returned from the cuisine link page
    if not cuisine_recipes:
        print "no content for:", cuisine_link
        return None  
    
    # convert web content to soup to better access the content
    soup_cuisine = BeautifulSoup(cuisine_recipes)

    # remove non-alphanumeric characters from recipe-count and convert it into integer
    return int(re.sub('\W', '', soup_cuisine.find("span",{"class": "recipe-count"}).get_text()))

# %%
def get_cuisine_pages(cuisine, page):
    # create link for given cuisine and page number and obtain recipe links from page 
    
    link = CUISINE_URL.format(str(page), cuisine)
    cuisine_recipe_links = get_content_from_url(link)
    if not cuisine_recipe_links:
        print "no content for:", link
        return None
    
    soup_search = BeautifulSoup(cuisine_recipe_links)

    # return the list of links for the cuisine page
    return soup_search.find("div",{"id":"article-list"}).find_all("h3")

# %%
def get_recipe(r_link):
    # make web request and obtain site content for recipe page
    recipe_link = RECIPE_URL.format(r_link)
    recipe_response = get_content_from_url(recipe_link)
    if not recipe_response:
        print "no content for:", recipe_link
        return None
    
    return BeautifulSoup(recipe_response)

# %%
def get_recipe_title(soup_recipe):
    # recipe title
    return soup_recipe.find("h1",{"class":"fn"}).get_text()

# %%
def get_recipe_chef(soup_recipe):
    # recipe chef name
    chef_name = soup_recipe.find("span",{"class":"author"})
    
    # if chef name is not there for the recipe
    if not chef_name:
        return None
    
    return chef_name.get_text()

# %%
def get_description(soup_recipe):
    # recipe description
    summary = soup_recipe.find("span",{"class":"summary"})
    
    # if summary is not there for the recipe
    if not summary:
        return None
    
    return summary.get_text()

# %%
def get_recipe_ingredients(soup_recipe):
    # recipe ingredients
    ingredients_list = soup_recipe.find_all("p", {"class":"ingredient"})
    ingredients = []
    for ing in ingredients_list:
        ingredients.append(ing.get_text())
    return ingredients

# %%
def get_recipe_preperation(soup_recipe):
    # recipe preperation steps
    prep_steps = soup_recipe.find_all("li", {"class":"instruction"})
    prep = []
    for step in prep_steps:
        # get text for the each step and strip of new line characters at both ends
        prep.append(step.get_text().strip())
    return prep

# %%
def get_recipe_time(soup_recipe):
    # recipe preperation time
    prep_time = soup_recipe.find("span", {"class":"prepTime"})
    # if recipe has prep_time given
    if prep_time:
        prep_time = prep_time.get_text()
    else:
        prep_time = None
    # recipe cooking time
    cooking_time = soup_recipe.find("span", {"class":"cookTime"})
    # if recipe has cooking_time given
    if cooking_time:
        cooking_time = cooking_time.get_text()
    else:
        cooking_time = None
    return prep_time, cooking_time

# %%
def get_servings(soup_recipe):
    # recipe servings
    servings = soup_recipe.find("h3", {"class":"yield"})
    if not servings:
        return None
    return servings.get_text()

# %%
def get_recommendations(soup_recipe):
    # recipe recommendations
    recommendations = soup_recipe.find("h2", {"class":"description"})
    if not recommendations:
        return None
    
    return recommendations.get_text()

# %%
def get_image_source(soup_recipe):
    # recipe image source
    image_source = soup_recipe.find("img", {"id":"food-image"})
    if not image_source:
        return None
    
    return image_source["src"]

# %%
def get_recipe_details(recipe_links):
    # obtain necessary recipe details from recipe page
    
    cuisine_recipes = {}
    
    # loop over recipe links to get recipe details for each recipe page
    for r in recipe_links:
        recipe = {}
        recipe['r_link'] = r.a["href"]
        print "recipe link: ", recipe['r_link']
        
        sleep(SCRAPING_REQUEST_STAGGER)        
        soup_recipe = get_recipe(recipe['r_link'])
        
        recipe['recipe title'] = get_recipe_title(soup_recipe)
        recipe['chef'] = get_recipe_chef(soup_recipe)
        recipe['description'] = get_description(soup_recipe)
        recipe['ingredient list'] = get_recipe_ingredients(soup_recipe)
        recipe['preperation steps'] = get_recipe_preperation(soup_recipe)
        recipe['prep_time'], recipe['cook_time'] = get_recipe_time(soup_recipe)
        recipe['servings'] = get_servings(soup_recipe)
        recipe['recommendations'] = get_recommendations(soup_recipe)
        recipe['image_source'] = get_image_source(soup_recipe)
        
        cuisine_recipes[recipe['recipe title']] = recipe
    
    return cuisine_recipes

# %%
def get_recipe_links(cuisine, pages):
    # loop over each page in the cuisine to obtain all the recipe details
    recipe_links = []
    
    for page in xrange(1, pages + 1):
        sleep(SCRAPING_REQUEST_STAGGER)
        # recipe links from each cuisine search page
        recipe_links.extend(get_cuisine_pages(cuisine, page))
        
    cuisine_recipes = get_recipe_details(recipe_links)
    return cuisine_recipes

# %%
def get_cuisine_recipes(cuisines):
    # loop over each cuisine and store data regarding that cuisine recipies
    
    # to store the data in a pandas Dataframe
    cuisine_df = pd.DataFrame()
    
    for cuisine in cuisines:
        cuisine_dict = {}
        
        cuisine_dict['cuisine'] = cuisine
        cuisine_dict['source'] = 'BBC Food'
        
        # convert text to lower case and replace all spaces in the cuisine title with '_', as used by website
        cuisine_no_space = cuisine.lower().replace(" ", "_")
        
        # obtain the number of recipes for each cuisine
        cuisine_dict['num_recipes'] = get_number_of_recipes(cuisine_no_space)
        
        # convert number of recipes into pages to scrape
        cuisine_dict['pages'] = int(ceil(cuisine_dict['num_recipes'] / NUMBER_OF_RECIPES_PER_PAGE))

        # print the cuisine details
        print '#####'
        print "Cuisine: %s \t Number of recipes: %d \t\t Number of pages: %d" \
                    % (cuisine, cuisine_dict['num_recipes'], cuisine_dict['pages'])
        
        cuisine_dict['recipes_details'] = get_recipe_links(cuisine_no_space, cuisine_dict['pages'])
    
        #coll.insert_one(cuisine_dict)
        
        # convert the dictionary into a dataframe and append it to the final dataframe
        cuisine_df = cuisine_df.append(pd.DataFrame.from_dict(cuisine_dict, orient='columns'), ignore_index=True)
        
    return cuisine_df

# %%
if __name__ == '__main__':
    
    # list of cuisines on BBC Food
    cuisines = ['Thai and South-east Asian']#'African', 'American', 'British', 'Caribbean', 'Chinese', , 'French', 'Greek', 'Indian', 'Irish', 'Italian', 'Japanese', 'Mexican', 'Nordic', 'North African', 'Portuguese', 'South American', 'Spanish', 'Thai and South-east Asian', 'Turkish and Middle Eastern']
    #coll.delete_many({})
    cuisine_dataframe = get_cuisine_recipes(cuisines)
    # the A's and C's are not there in mongo
# Out:
# #####
# Cuisine: Thai and South-east Asian 	 Number of recipes: 223 		 Number of pages: 15
# recipe link:  /food/recipes/nasi_goreng_with_lime_87031
# recipe link:  /food/recipes/thai_prawn_curry_with_09136
# recipe link:  /food/recipes/halibut_with_spicy_37680
# recipe link:  /food/recipes/stirfrylimeandcoconu_80402
# recipe link:  /food/recipes/thai_noodles_with_72276
# recipe link:  /food/recipes/hot_and_spicy_thai_squid_01824
# recipe link:  /food/recipes/nice_and_spicy_thai_90314
# recipe link:  /food/recipes/sea_bass_with_spring_70065
# recipe link:  /food/recipes/chickenlimeandcashew_4133
# recipe link:  /food/recipes/helens_coconut_pandan_32016
# recipe link:  /food/recipes/summer_salad_with_72489
# recipe link:  /food/recipes/thaigreenchickencurr_92440
# recipe link:  /food/recipes/whole_baked_seabass_with_36512
# recipe link:  /food/recipes/grilled_lamb_chops_with_01274
# recipe link:  /food/recipes/mickeys_khao_soi_noodles_24933
# recipe link:  /food/recipes/bobbys_vegetables_cooked_00387
# recipe link:  /food/recipes/bobbys_banana_leaf-baked_35050
# recipe link:  /food/recipes/thai_beef_and_mango_98996
# recipe link:  /food/recipes/spicy_soft_shell_crab_29297
# recipe link:  /food/recipes/coconutfishcurry_89979
# recipe link:  /food/recipes/root_vegetable_thai_74828
# recipe link:  /food/recipes/stir-fried_chilli_pork_54692
# recipe link:  /food/recipes/salmon_rendang_with_mint_04196
# recipe link:  /food/recipes/sweetandsourshrimpan_88523
# recipe link:  /food/recipes/thai_massaman_chicken_82428
# recipe link:  /food/recipes/turbot_with_a_ginger_and_48467
# recipe link:  /food/recipes/thaipeanutvegetablea_85256
# recipe link:  /food/recipes/malaysian-style_chicken_98338
# recipe link:  /food/recipes/chicken_pho_97726
# recipe link:  /food/recipes/turkeysaladwithchine_92947
# recipe link:  /food/recipes/srilankanturkeycurry_92946
# recipe link:  /food/recipes/indonesianstirfriedr_92945
# recipe link:  /food/recipes/thai-style_cucumber_08091
# recipe link:  /food/recipes/chicken_meatballs_in_27036
# recipe link:  /food/recipes/fiery_octopus_ojingeo_90139
# recipe link:  /food/recipes/coconut_and_sticky_rice_52999
# recipe link:  /food/recipes/penang_fish_curry_70583
# recipe link:  /food/recipes/white_radish_salad_90778
# recipe link:  /food/recipes/lotus_leaf_wraps_lo_mai_65211
# recipe link:  /food/recipes/thai_crab_risotto_with_18400
# recipe link:  /food/recipes/thai_jungle_curry_13331
# recipe link:  /food/recipes/thai_lamb_salad_with_26133
# recipe link:  /food/recipes/thai_vegetable_curry_41763
# recipe link:  /food/recipes/beef_rendang_62793
# recipe link:  /food/recipes/vietnamese_beef_and_57283
# recipe link:  /food/recipes/lemon_and_lime_chicken_27815
# recipe link:  /food/recipes/rich_prawn_curry_98414
# recipe link:  /food/recipes/how_to_make_thai_green_83259
# recipe link:  /food/recipes/how_to_make_thai_green_67270
# recipe link:  /food/recipes/chilli_beef_rendang_47873
# recipe link:  /food/recipes/haddock_parcels_and_76666
# recipe link:  /food/recipes/soy_and_honey_chicken_37066
# recipe link:  /food/recipes/thairedpenangcurry_90828
# recipe link:  /food/recipes/thai_beef__mixed_pepper_58157
# recipe link:  /food/recipes/chilli_pork_with_82478
# recipe link:  /food/recipes/tomkhasoup_93592
# recipe link:  /food/recipes/malaylambkorma_93512
# recipe link:  /food/recipes/thaisteamedsalmon_7254
# recipe link:  /food/recipes/prawn_and_mint_finger_12608
# recipe link:  /food/recipes/asian_slaw_78952
# recipe link:  /food/recipes/thaistylechickencurr_83844
# recipe link:  /food/recipes/malaysianspicednoodl_88721
# recipe link:  /food/recipes/chicken_pad_thai_96522
# recipe link:  /food/recipes/pinapple_prawn_and_02199
# recipe link:  /food/recipes/amysspicynyonyachick_91828
# recipe link:  /food/recipes/thaistylefishcakes_90298
# recipe link:  /food/recipes/chickenandbambooshoo_90183
# recipe link:  /food/recipes/thaistylebeefsalad_90297
# recipe link:  /food/recipes/seared_tuna_with_glass_05316
# recipe link:  /food/recipes/super_satay_chicken_06986
# recipe link:  /food/recipes/duck_and_lemongrass_18615
# recipe link:  /food/recipes/chargrilled_seabass_62243
# recipe link:  /food/recipes/thai_roast_chicken_with_58724
# recipe link:  /food/recipes/asian-braised_shin_of_98140
# recipe link:  /food/recipes/spicedchickendumplin_91221
# recipe link:  /food/recipes/beefrendangwithlemon_90061
# recipe link:  /food/recipes/soypoachedchickenwit_83921
# recipe link:  /food/recipes/tomyumsoup_85069
# recipe link:  /food/recipes/stirfryvegetarianpha_70987
# recipe link:  /food/recipes/vietnamesescallopswi_91368
# recipe link:  /food/recipes/leelikolminicurrygre_12734
# recipe link:  /food/recipes/pad_thai_36788
# recipe link:  /food/recipes/chilli_and_lemongrass_73685
# recipe link:  /food/recipes/spicy_lemongrass_chicken_46810
# recipe link:  /food/recipes/singapore_chilli_crab_83663
# recipe link:  /food/recipes/jungle_curry_of_guinea_73580
# recipe link:  /food/recipes/thai_roast_chicken_92130
# recipe link:  /food/recipes/beef_rendang_with_mango_78223
# recipe link:  /food/recipes/thaigreenchickencurr_86295
# recipe link:  /food/recipes/thai_fish_cakes_with_a_37638
# recipe link:  /food/recipes/spiced_chicken_and_53621
# recipe link:  /food/recipes/thai_beef_stir_fry_28048
# recipe link:  /food/recipes/crispy_noodles_with_80051
# recipe link:  /food/recipes/griddled_pork_chop_with_18559
# recipe link:  /food/recipes/morecombebayshrimpan_85714
# recipe link:  /food/recipes/thai_green_curry_with_67823
# recipe link:  /food/recipes/slow_cooker_massaman_65836
# recipe link:  /food/recipes/lobster_thai_curry_with_47060
# recipe link:  /food/recipes/spicedsaladofbraised_84246
# recipe link:  /food/recipes/seabasswithlimeandle_84589
# recipe link:  /food/recipes/lamb_rendang_with_83481
# recipe link:  /food/recipes/beefrendang_78767
# recipe link:  /food/recipes/nigelslatersthaigree_80244
# recipe link:  /food/recipes/thaistylechickencurr_86976
# recipe link:  /food/recipes/south-east_asian_23221
# recipe link:  /food/recipes/lobster_red_thai_curry_84326
# recipe link:  /food/recipes/chickensaladwiththai_91766
# recipe link:  /food/recipes/stir-fry_beef_with_53740
# recipe link:  /food/recipes/spicy_sesame_vegetable_12407
# recipe link:  /food/recipes/aromatic_thai_green_31771
# recipe link:  /food/recipes/thai-style_fishcakes_68632
# recipe link:  /food/recipes/glass_noodle_salad_with_39907
# recipe link:  /food/recipes/salmon_pad_thai_85183
# recipe link:  /food/recipes/singapore_chilli_king_94592
# recipe link:  /food/recipes/prawn_and_broccoli_pad_35502
# recipe link:  /food/recipes/thaiinspirednoodleso_92377
# recipe link:  /food/recipes/steamed_thai_chicken_99778
# recipe link:  /food/recipes/thai_coconut-chilli_60337
# recipe link:  /food/recipes/thai_poached_pork_belly_75251
# recipe link:  /food/recipes/oysters_vietnamese-style_01341
# recipe link:  /food/recipes/thaispicedsteamedmus_92026
# recipe link:  /food/recipes/shredded_lamb_thai_salad_67863
# recipe link:  /food/recipes/isleofmanqueeniescal_87332
# recipe link:  /food/recipes/tomyumsoupwithlimean_74618
# recipe link:  /food/recipes/butternutsquashandpr_88913
# recipe link:  /food/recipes/thaiseabasswithholyb_91552
# recipe link:  /food/recipes/peanut_chicken_with_54593
# recipe link:  /food/recipes/beeffilletwithcoconu_87454
# recipe link:  /food/recipes/orientalvegetablekeb_6552
# recipe link:  /food/recipes/thaigreencurry_67788
# recipe link:  /food/recipes/chickenwithsataysauc_70986
# recipe link:  /food/recipes/thaifishcakesservedw_73733
# recipe link:  /food/recipes/thai_spiced_fish_pie_93756
# recipe link:  /food/recipes/singapore_noodles_69488
# recipe link:  /food/recipes/greencurrypaste_67789
# recipe link:  /food/recipes/red_braised_pork_ribs_08768
# recipe link:  /food/recipes/malaysian_beef_and_09964
# recipe link:  /food/recipes/thai_fish_cakes_62537
# recipe link:  /food/recipes/panfriedfishwithgree_73071
# recipe link:  /food/recipes/redsnapperwithcoconu_86477
# recipe link:  /food/recipes/thaistylefishcakes_88722
# recipe link:  /food/recipes/thaisteamedsalmonwit_74781
# recipe link:  /food/recipes/padthai_67953
# recipe link:  /food/recipes/indonesianporkcurry_412
# recipe link:  /food/recipes/thaiporkcurry_72072
# recipe link:  /food/recipes/nasi_goreng_69542
# recipe link:  /food/recipes/spicy_crab_cakes_with_78572
# recipe link:  /food/recipes/thaiporkkebabs_67596
# recipe link:  /food/recipes/griddledauberginesal_84602
# recipe link:  /food/recipes/aromaticsalmoncooked_1608
# recipe link:  /food/recipes/greenchickencurry_70891
# recipe link:  /food/recipes/auberginesatayskewer_92178
# recipe link:  /food/recipes/coconutbutternutsqua_65609
# recipe link:  /food/recipes/balinesericepudding_93363
# recipe link:  /food/recipes/coriandersearedtunao_10343
# recipe link:  /food/recipes/stirfriedporkwithchi_10291
# recipe link:  /food/recipes/panfriedwholecrabwit_10111
# recipe link:  /food/recipes/singaporestylenoodle_91668
# recipe link:  /food/recipes/isaanstylegrilledchi_91586
# recipe link:  /food/recipes/aubergineandtofusata_8816
# recipe link:  /food/recipes/thairoastedcrabrisot_83892
# recipe link:  /food/recipes/crabandsweetcornsoup_89965
# recipe link:  /food/recipes/brillenpapillote_88911
# recipe link:  /food/recipes/spicedcrabcakeswiths_88291
# recipe link:  /food/recipes/thaistylemushroombro_88292
# recipe link:  /food/recipes/hoiancrispybeef_81504
# recipe link:  /food/recipes/kingprawnpadthai_86372
# recipe link:  /food/recipes/monkfishtailbakedina_86538
# recipe link:  /food/recipes/ayamgolekspicedchick_86656
# recipe link:  /food/recipes/spicedlambricevermic_87817
# recipe link:  /food/recipes/thaistyleredmackerel_87483
# recipe link:  /food/recipes/crabnoodlesaladwithn_86637
# recipe link:  /food/recipes/glazedbokchoiwithcri_82542
# recipe link:  /food/recipes/redvegetablecurry_72803
# recipe link:  /food/recipes/thaicurrywithhomemad_71275
# recipe link:  /food/recipes/thaicurrywithmackere_11072
# recipe link:  /food/recipes/thaimonkfishandokrac_83780
# recipe link:  /food/recipes/grilledlemongrassbee_79306
# recipe link:  /food/recipes/thaistyleduckredcurr_85145
# recipe link:  /food/recipes/grilledmarinatedchic_65951
# recipe link:  /food/recipes/thaichickencakeswith_66006
# recipe link:  /food/recipes/thaichickenpattieswi_70011
# recipe link:  /food/recipes/grilledmarinatedchic_65951
# recipe link:  /food/recipes/ricksteinsgrilledlem_10665
# recipe link:  /food/recipes/vietnamesecrabsaladw_83679
# recipe link:  /food/recipes/chinesestyleporkpatt_84653
# recipe link:  /food/recipes/potatocakeswithspicy_84276
# recipe link:  /food/recipes/thaibeefpatties_84008
# recipe link:  /food/recipes/sesameprawntoasts_83935
# recipe link:  /food/recipes/crabcakeswithchillis_83757
# recipe link:  /food/recipes/sataysauce_81544
# recipe link:  /food/recipes/bangbangchicken_82544
# recipe link:  /food/recipes/crispynoodlecakewith_82462
# recipe link:  /food/recipes/vietnameseprawnsonsu_81503
# recipe link:  /food/recipes/halongcrabandwhitefi_81506
# recipe link:  /food/recipes/chickenandmangosalad_80105
# recipe link:  /food/recipes/redthaichickencurryw_80103
# recipe link:  /food/recipes/thaistyleseabass_78365
# recipe link:  /food/recipes/thaistylesteamedseab_78366
# recipe link:  /food/recipes/orientalthaibeefsala_78245
# recipe link:  /food/recipes/simplepeanutsauce_71805
# recipe link:  /food/recipes/chargrilledthaibeefs_73736
# recipe link:  /food/recipes/deepfriedvegetablesw_70708
# recipe link:  /food/recipes/greenthaikebabsandpa_74817
# recipe link:  /food/recipes/thaifragrantsalmonwi_72333
# recipe link:  /food/recipes/thaigreenrice_68034
# recipe link:  /food/recipes/vietnamesebeefandspi_71363
# recipe link:  /food/recipes/fruitkebabskewers_10298
# recipe link:  /food/recipes/vietnamesegrilledchi_74809
# recipe link:  /food/recipes/seafoodlaksawithgrid_1011
# recipe link:  /food/recipes/massamancurrypaste_4953
# recipe link:  /food/recipes/thaispicedburgers_70173
# recipe link:  /food/recipes/vietnamesestyleprawn_12154
# recipe link:  /food/recipes/duckwraps_71806
# recipe link:  /food/recipes/gadogadoindonesianve_71808
# recipe link:  /food/recipes/sweetandsourmussells_73658
# recipe link:  /food/recipes/duckwithmangosalsa_72997
# recipe link:  /food/recipes/bhindibhajji_74849
# recipe link:  /food/recipes/hotandsourprawnswith_72269
# recipe link:  /food/recipes/malaysianprawnfritte_71364
# recipe link:  /food/recipes/seafoodlaksa_66343
# recipe link:  /food/recipes/thainoodles_66007
# recipe link:  /food/recipes/greenbeanswoktossedw_74499

# %%
cuisine_dataframe
# Out:
#                        cuisine  num_recipes  pages  \
# 0    Thai and South-east Asian          223     15
# 1    Thai and South-east Asian          223     15
# 2    Thai and South-east Asian          223     15
# 3    Thai and South-east Asian          223     15
# 4    Thai and South-east Asian          223     15
# 5    Thai and South-east Asian          223     15
# 6    Thai and South-east Asian          223     15
# 7    Thai and South-east Asian          223     15
# 8    Thai and South-east Asian          223     15
# 9    Thai and South-east Asian          223     15
# 10   Thai and South-east Asian          223     15
# 11   Thai and South-east Asian          223     15
# 12   Thai and South-east Asian          223     15
# 13   Thai and South-east Asian          223     15
# 14   Thai and South-east Asian          223     15
# 15   Thai and South-east Asian          223     15
# 16   Thai and South-east Asian          223     15
# 17   Thai and South-east Asian          223     15
# 18   Thai and South-east Asian          223     15
# 19   Thai and South-east Asian          223     15
# 20   Thai and South-east Asian          223     15
# 21   Thai and South-east Asian          223     15
# 22   Thai and South-east Asian          223     15
# 23   Thai and South-east Asian          223     15
# 24   Thai and South-east Asian          223     15
# 25   Thai and South-east Asian          223     15
# 26   Thai and South-east Asian          223     15
# 27   Thai and South-east Asian          223     15
# 28   Thai and South-east Asian          223     15
# 29   Thai and South-east Asian          223     15
# ..                         ...          ...    ...
# 189  Thai and South-east Asian          223     15
# 190  Thai and South-east Asian          223     15
# 191  Thai and South-east Asian          223     15
# 192  Thai and South-east Asian          223     15
# 193  Thai and South-east Asian          223     15
# 194  Thai and South-east Asian          223     15
# 195  Thai and South-east Asian          223     15
# 196  Thai and South-east Asian          223     15
# 197  Thai and South-east Asian          223     15
# 198  Thai and South-east Asian          223     15
# 199  Thai and South-east Asian          223     15
# 200  Thai and South-east Asian          223     15
# 201  Thai and South-east Asian          223     15
# 202  Thai and South-east Asian          223     15
# 203  Thai and South-east Asian          223     15
# 204  Thai and South-east Asian          223     15
# 205  Thai and South-east Asian          223     15
# 206  Thai and South-east Asian          223     15
# 207  Thai and South-east Asian          223     15
# 208  Thai and South-east Asian          223     15
# 209  Thai and South-east Asian          223     15
# 210  Thai and South-east Asian          223     15
# 211  Thai and South-east Asian          223     15
# 212  Thai and South-east Asian          223     15
# 213  Thai and South-east Asian          223     15
# 214  Thai and South-east Asian          223     15
# 215  Thai and South-east Asian          223     15
# 216  Thai and South-east Asian          223     15
# 217  Thai and South-east Asian          223     15
# 218  Thai and South-east Asian          223     15
#
#                                        recipes_details    source
# 0    {u'cook_time': u'30 mins to 1 hour', u'descrip...  BBC Food
# 1    {u'cook_time': u'30 mins to 1 hour', u'descrip...  BBC Food
# 2    {u'cook_time': u'30 mins to 1 hour', u'descrip...  BBC Food
# 3    {u'cook_time': u'No cooking required', u'descr...  BBC Food
# 4    {u'cook_time': u'Over 2 hours', u'description'...  BBC Food
# 5    {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 6    {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 7    {u'cook_time': u'30 mins to 1 hour', u'descrip...  BBC Food
# 8    {u'cook_time': u'30 mins to 1 hour', u'descrip...  BBC Food
# 9    {u'cook_time': u'30 mins to 1 hour', u'descrip...  BBC Food
# 10   {u'cook_time': u'Less than 10 mins', u'descrip...  BBC Food
# 11   {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 12   {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 13   {u'cook_time': u'1 to 2 hours', u'description'...  BBC Food
# 14   {u'cook_time': u'Over 2 hours', u'description'...  BBC Food
# 15   {u'cook_time': u'1 to 2 hours', u'description'...  BBC Food
# 16   {u'cook_time': u'1 to 2 hours', u'description'...  BBC Food
# 17   {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 18   {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 19   {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 20   {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 21   {u'cook_time': u'No cooking required', u'descr...  BBC Food
# 22   {u'cook_time': u'30 mins to 1 hour', u'descrip...  BBC Food
# 23   {u'cook_time': u'Less than 10 mins', u'descrip...  BBC Food
# 24   {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 25   {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 26   {u'cook_time': u'Over 2 hours', u'description'...  BBC Food
# 27   {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 28   {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 29   {u'cook_time': u'30 mins to 1 hour', u'descrip...  BBC Food
# ..                                                 ...       ...
# 189  {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 190  {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 191  {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 192  {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 193  {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 194  {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 195  {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 196  {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 197  {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 198  {u'cook_time': u'Less than 10 mins', u'descrip...  BBC Food
# 199  {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 200  {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 201  {u'cook_time': u'Less than 10 mins', u'descrip...  BBC Food
# 202  {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 203  {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 204  {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 205  {u'cook_time': u'30 mins to 1 hour', u'descrip...  BBC Food
# 206  {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 207  {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 208  {u'cook_time': u'Less than 10 mins', u'descrip...  BBC Food
# 209  {u'cook_time': u'Less than 10 mins', u'descrip...  BBC Food
# 210  {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 211  {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 212  {u'cook_time': u'Less than 10 mins', u'descrip...  BBC Food
# 213  {u'cook_time': u'No cooking required', u'descr...  BBC Food
# 214  {u'cook_time': u'Less than 10 mins', u'descrip...  BBC Food
# 215  {u'cook_time': u'Less than 10 mins', u'descrip...  BBC Food
# 216  {u'cook_time': u'10 to 30 mins', u'description...  BBC Food
# 217  {u'cook_time': u'Less than 10 mins', u'descrip...  BBC Food
# 218  {u'cook_time': u'No cooking required', u'descr...  BBC Food
#
# [219 rows x 5 columns]

# %%
cuisine_dataframe.to_csv("recipes_data_BBC_Food_Thai_and_South-east_Asian.csv")

# %% [markdown]
# cuisines = ['indian']
#
# for l in links:
#     print (l.a["href"])
#     #print single_query("http://www.bbc.co.uk{}".format(l.a["href"]))
#
# namespace['recipe_str_%s_%d_1' % (cuisine, page)] = single_query("http://www.bbc.co.uk{}".format(l.a["href"]))
#
# namespace['recipe_str_%s_%d_1' % (cuisine, page)]
#
# soup = BeautifulSoup(namespace['recipe_str_%s_%d_1' % (cuisine, page)])
# recipe_title = soup.find("div",{"class":"article-title"}).find("h1").get_text()
# description_summary = soup.find("span",{"class":"summary"}).get_text()
# ingredient_list = soup.find_all("p",{"class":"ingredient"})
#
# namespace['ingredients_%s_%s' % (cuisine, recipe_title[:20])] = []
#
# for ing in ingredient_list:
#     namespace['ingredients_with quant_%s_%s' % (cuisine, recipe_title[:20])].append(ing.get_text())
#
# prep_steps = soup.find("div",{"id":"preparation"}).find("ol", {"class":"instructions"}).find_all("li")
#
# namespace['prep_%s_%s' % (cuisine, recipe_title[:20])] = []
# for step in prep_steps:
#     namespace['prep_%s_%s' % (cuisine, recipe_title[:20])].append(step.get_text().strip())

# %% [markdown]
# namespace.keys()

# %% [markdown]
# list1 = [1, 2, 3, 4]
# list2 = [2, 3, 4, 5]
# d1 = {'recipe': "a", "desc": 'b', 'prep': 'c'}
# d2 = {'recipe': "d", "desc": 'e', 'prep': 'f'}
# d3 = {}
# d3[d1['recipe']] = d1
# d3[d2['recipe']] = d2
